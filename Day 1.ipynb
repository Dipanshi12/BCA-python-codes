# %%
print("Hello Dipanshi")
# Out:
# Hello Dipanshi

# %%
num =int(input("enter a number :"))
print(num)
# Out:
# enter a number : 5
# 5

# %%
num =int(input("enter a number :"))
if num%2==0:
   print("even")
else:
   print("odd")
# Out:
# enter a number : 5
# odd

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a >= b and a >= c:
    print("Largest number is:", a)
elif b >= a and b >= c:
    print("Largest number is:", b)
else:
    print("Largest number is:", c)
# Out:
# Enter first number:  7
# Enter second number:  11
# Enter third number:  5
# Largest number is: 11

# %%
text =input("enter a string:")
reverse =text[::-1]
print("reversed string is:", reverse)
# Out:
# enter a string: dipanshi
# reversed string is: ihsnapid

# %%
text =input("enter a string:")
count = 0
for ch in text.lower():
 if ch =='a' or ch =='e' or ch =='i' or ch =='o' or ch =='u':
   count += 1
print("Number of vowels:",count)
# Out:
# enter a string: DIPANSHI
# Number of vowels: 3

# %%
a =int(input("enter first number:"))
b =int(input("enter second number:"))

sum = a + b
diffrence = a - b
multiplication = a * b
division = a / b
modulus = a % b
print("sum is:", sum)
print("diffrence is:", diffrence)
print("multiplication is:", multiplication)
print("division is:", division)
print("modulus is:", modulus)
# Out:
# enter first number: 6
# enter second number: 5
# sum is: 11
# diffrence is: 1
# multiplication is: 30
# division is: 1.2
# modulus is: 1

# %%
a = int(input("enter a number:"))

if not a >=5:
    print("True")
# Out:
# enter a number: 2
# True

# %%
a = [1,2,3,4,5,6]
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
b = [14]
print(type(b))
# Out:
# <class 'list'>

# %%
a = (9,)
print(type(a))
# Out:
# <class 'tuple'>

# %%
a = (9)
print(type(a))
# Out:
# <class 'int'>

# %%
marks =[89,87,53,75,58]
print(len(marks))
# Out:
# 5

# %%
marks =[89,87,53,75,58]
print(marks[::-1])
# Out:
# [58, 75, 53, 87, 89]

# %%
marks =[89,87,53,75,58]
marks.append(34)
print(marks)
# Out:
# [89, 87, 53, 75, 58, 34]

# %%
marks.pop()
print(marks)
# Out:
# [89, 87, 53, 75, 58]

# %%
marks.pop(2)
print(marks)
# Out:
# [89, 87, 75, 58]

# %%
marks.insert(2,100)
print(marks)
# Out:
# [89, 87, 100, 75, 58]

# %%
marks.clear()
print(marks)
# Out:
# []

# %%
marks =[89,87,53,75,58]
marks.remove(53)
print(marks)
# Out:
# [89, 87, 75, 58]

# %%
marks =[5,5,5,2,89,87,2,53,7,2,5,58]
c = marks.index(2)
print(c)
# Out:
# 3

# %%
marks =[5,5,5,2,89,87,2,53,7,2,5,58]
marks.sort()
print(marks)
# Out:
# [2, 2, 2, 5, 5, 5, 5, 7, 53, 58, 87, 89]

# %%
marks.reverse()
print(marks)
# Out:
# [89, 87, 58, 53, 7, 5, 5, 5, 5, 2, 2, 2]

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\hp
